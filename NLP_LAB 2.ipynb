# %% [markdown]
# # Lab_2

# %%
# STEMMING OF WORDS
import nltk
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('happiness')
# Out:
# 'happi'

# %%
import nltk
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('drinking')
# Out:
# 'drink'

# %%
import nltk
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('swimming')
# Out:
# 'swim'

# %%
import nltk
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('laugh')
stemmerporter.stem('terribly')
# Out:
# 'terribl'

# %%
import nltk
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('laughing')
# Out:
# 'laugh'

# %%
from nltk.stem import LancasterStemmer
stemmerLan = LancasterStemmer()
stemmerLan.stem('happiness')
# Out:
# 'happy'

# %%
import nltk
from nltk.stem import RegexpStemmer
stemmerregexp = RegexpStemmer('ing')
stemmerregexp.stem('singing')
# Out:
# 's'

# %%
import nltk
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
frenchstemmer =  SnowballStemmer('french')
frenchstemmer .stem('manges')
# Out:
# 'mang'

# %%
import nltk
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
frenchstemmer =  SnowballStemmer('french')  # GERMAN
frenchstemmer .stem('Elle est la Mainson')
# Out:
# 'elle est la mainson'

# %%
# HOMEWORK SNOWBALL STEMMING IN HINDI / TAMIL / GERMAN
"""
NLTK only supports(
languages = (
        "arabic",
        "danish",
        "dutch",
        "english",
        "finnish",
        "french",
        "german",
        "hungarian",
        "italian",
        "norwegian",
        "porter",
        "portuguese",
        "romanian",
        "russian",
        "spanish",
        "swedish",
    ))

"""
import nltk
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
frenchstemmer =  SnowballStemmer('german')  # GERMAN
frenchstemmer .stem('Es freut mich, dich kennenzulernen.')
# Out:
# 'es freut mich, dich kennenzulernen.'

# %%
import nltk
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
frenchstemmer =  SnowballStemmer('german')  # GERMAN
frenchstemmer .stem('Es')
# Out:
# 'es'

# %%
# STEMMING PARAGRAPH
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
example = "Am quick fox jumps over a lazy dog"
example = [stemmer.stem(token) for token in example.split(" ")]
print(" ".join(example))
# Out:
# Am quick fox jump over a lazi dog

# %%
# LEMMATIZER
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("cacti"))
# Out:
# cactus

# %%
# LEMMATIZER
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("formulae"))
# Out:
# formula

# %%
# LEMMATIZER
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("stimulae"))
# Out:
# stimulae

# %%
print(lemmatizer.lemmatize("better",pos = 'a'))
# Out:
# good

# %%
print(lemmatizer.lemmatize("Am"))
# Out:
# Am

# %%
print(lemmatizer.lemmatize("am",pos = 'v'))
# Out:
# be

# %%
# PRONOUNS
# !pip install jieba

# %%
# CHINESE SEGMENTATION USING JIEBA
import jieba
seg = jieba.cut("我要和朋友们去上学", cut_all = True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\buyre\AppData\Local\Temp\jieba.cache
# Loading model cost 1.412 seconds.
# Prefix dict has been built successfully.
# 我 要 和 朋友 们 去 上学

# %%
# BASIC TEXT PIPELINING PROCESSING
import nltk
sent = "Become an expert in NLP!"
words = nltk.word_tokenize(sent)
print(words)
# Out:
# ['Become', 'an', 'expert', 'in', 'NLP', '!']

# %%
import nltk
sent = "St. Joseph Convent Higher Secondary School was founded on 11th February 1963. It is owned by the Congregation of the Sisters of Saint Joseph of Chambery an International congregation. "
words = nltk.word_tokenize(sent)
print(words)
# Out:
# ['St.', 'Joseph', 'Convent', 'Higher', 'Secondary', 'School', 'was', 'founded', 'on', '11th', 'February', '1963', '.', 'It', 'is', 'owned', 'by', 'the', 'Congregation', 'of', 'the', 'Sisters', 'of', 'Saint', 'Joseph', 'of', 'Chambery', 'an', 'International', 'congregation', '.']

# %%
# WORD TOKENIZE
texts = """Snowball is a small string processing programming language designed for creating stemming algorithms for use in information retrieval.
The basic datatypes handled by Snowball are strings of characters, signed integers, and boolean truth values, or more simply strings, integers and booleans."""

for text in texts:
    sentences = nltk.sent_tokenize(texts)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        print(words)
        tagged = nltk.pos_tag(words)
        print(tagged)
# Out:
# ['Snowball', 'is', 'a', 'small', 'string', 'processing', 'programming', 'language', 'designed', 'for', 'creating', 'stemming', 'algorithms', 'for', 'use', 'in', 'information', 'retrieval', '.']
# [('Snowball', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('small', 'JJ'), ('string', 'NN'), ('processing', 'NN'), ('programming', 'JJ'), ('language', 'NN'), ('designed', 'VBN'), ('for', 'IN'), ('creating', 'VBG'), ('stemming', 'VBG'), ('algorithms', 'NN'), ('for', 'IN'), ('use', 'NN'), ('in', 'IN'), ('information', 'NN'), ('retrieval', 'NN'), ('.', '.')]
# ['The', 'basic', 'datatypes', 'handled', 'by', 'Snowball', 'are', 'strings', 'of', 'characters', ',', 'signed', 'integers', ',', 'and', 'boolean', 'truth', 'values', ',', 'or', 'more', 'simply', 'strings', ',', 'integers', 'and', 'booleans', '.']
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
texts = ("St. Joseph Convent Higher Secondary School was founded on 11th February 1963.")
words = nltk.word_tokenize(texts)
print(words)
# Out:
# ['St.', 'Joseph', 'Convent', 'Higher', 'Secondary', 'School', 'was', 'founded', 'on', '11th', 'February', '1963', '.']
