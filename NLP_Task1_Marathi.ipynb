# %% [markdown]
# <h3 style="text-align: center;"><span style="color: #000fff;">Nagesh Buyre - 19MAI0024</span></h3>
# <h1 style="text-align: center;">Natural Language Processing</h1>
# <h3 style="text-align: center;">Activity - 1(Stemmer-Lemmatizer-POSTagger with some Marathi analysis!)</h3>

# %% [markdown]
# # INLTK Marathi

# %%
#importing inltk
#Inklt is indian nltk library supports around 20 indian laguages including sanskrit

import inltk

# %%
#Language setup
#hi - Hindi, mr - marathi, etc

from inltk.inltk import setup

#setup('mr')

#Once Setup is done the code goes on running and running!

# %%
#Marathi Courpus tokenization from inltk


from inltk.inltk import tokenize
text='माझा नाव '
tokenize(text ,'mr')
# Out:
# ['▁माझा', '▁नाव']

# %%
# Paragraph tokenization

from inltk.inltk import tokenize
text="""करोनाच्या संकटामुळे पदवीच्या अंतिम परीक्षा रद्द करण्याच्या निर्णयाने अपेक्षितपणे राजकीय वळण घेतले आहे. 
वैयक्तिक आणि सामाजिक उन्नतीसाठी आवश्यक असलेले शिक्षण ही एक राजकीय प्रक्रियाही आहे. म्हणूनच राजकीय पक्ष, 
विशेषत: सत्ताधारी त्याचा अतिशय खुबीने वापर करीत असतात. त्यामुळे परीक्षा रद्द करण्याच्या मुद्द्यावरून राजकारण होणे धक्कादायक नाही. 
या निर्णयावर सत्ताधारी आणि विरोधक वेगवेगळ्या टोकांवर असल्याने परीक्षा रद्द करणे योग्य की अयोग्य यांपैकी एकालाच अनुकूलता दर्शविली तर 
विशिष्ट राजकीय पक्षाच्या बाजूने कौल दिल्याचा समज होऊ शकतो; परंतु शिक्षणाकडे अशा काळ्या-पांढऱ्या चष्म्यातून पाहून चालणार नाही. 
करोनाचे संकट मोठे आहे आणि दोन महिन्यांहून अधिक काळ लॉकडाउन लावल्यानंतरही ते संपलेले नाही आणि इतक्यात संपण्याची चिन्हेही नाहीत. 
त्यामुळे शाळा-महाविद्यालयांतील अन्य इयत्तांप्रमाणे पदवीच्या अंतिम वर्षाची परीक्षाही रद्द करण्याचा राज्य सरकारचा निर्णय तर्कसंगत आणि विद्यार्थ्यांच्या 
आरोग्याच्या हिताचा आहे. मात्र, तो चुकीचा आहे. यातून विद्यार्थ्यांचे शैक्षणिक नुकसान होण्याचीच शक्यता अधिक आहे. 
शिक्षणाची मोठी परंपरा असलेल्या महाराष्ट्रात राष्ट्रीय आणि आंतरराष्ट्रीय पातळीवरील अनेक शिक्षणतज्ज्ञ आहेत. अशांपैकी काहींची समिती 
नेमून परीक्षांबाबत अन्य कोणकोणते पर्याय आहेत, प्राप्त परिस्थितीत कोणत्या पद्धतीने परीक्षा घेता येऊ शकते, देशात आणि जगात अन्यत्र काय प्रयोग 
केले जात आहेत याचा अभ्यास करून घ्यायला हवा होता. महामारीच्या कायद्यानुसार कोणताही निर्णय घेण्यास राज्य सरकार सक्षम असले, 
तरी आपल्या निर्णयाच्या सर्व संभाव्य परिणामांचा विचार होणे गरजेचेच आहे. 
यामुळेच याबाबतच्या वादाकडे राज्यपाल आणि सरकार यांच्यातील कलगीतुरा म्हणून न पाहता शैक्षणिक दृष्टिकोनातून पाहणे आवश्यक आहे."""
tokenize(text ,'mr')
# Out:
# ['▁करो',
#  'ना',
#  'च्या',
#  '▁संकट',
#  'ामुळे',
#  '▁पदवी',
#  'च्या',
#  '▁अंतिम',
#  '▁परीक्षा',
#  '▁रद्द',
#  '▁करण्याच्या',
#  '▁निर्णय',
#  'ाने',
#  '▁अपेक्षित',
#  'पणे',
#  '▁राजकीय',
#  '▁वळण',
#  '▁घेतले',
#  '▁आहे',
#  '.',
#  '▁वैयक्तिक',
#  '▁आणि',
#  '▁सामाजिक',
#  '▁उन्नतीसाठी',
#  '▁आवश्यक',
#  '▁असलेले',
#  '▁शिक्षण',
#  '▁ही',
#  '▁एक',
#  '▁राजकीय',
#  '▁प्रक्रिया',
#  'ही',
#  '▁आहे',
#  '.',
#  '▁म्हणूनच',
#  '▁राजकीय',
#  '▁पक्ष',
#  ',',
#  '▁विशेषत',
#  ':',
#  '▁सत्ताधारी',
#  '▁त्याचा',
#  '▁अतिशय',
#  '▁खु',
#  'बी',
#  'ने',
#  '▁वापर',
#  '▁करीत',
#  '▁असतात',
#  '.',
#  '▁त्यामुळे',
#  '▁परीक्षा',
#  '▁रद्द',
#  '▁करण्याच्या',
#  '▁मुद्',
#  'द्या',
#  'वरून',
#  '▁राजकारण',
#  '▁होणे',
#  '▁धक्का',
#  'दायक',
#  '▁नाही',
#  '.',
#  '▁या',
#  '▁निर्णय',
#  'ावर',
#  '▁सत्ताधारी',
#  '▁आणि',
#  '▁विरोधक',
#  '▁वेगवेगळ्या',
#  '▁टोक',
#  'ांवर',
#  '▁असल्याने',
#  '▁परीक्षा',
#  '▁रद्द',
#  '▁करणे',
#  '▁योग्य',
#  '▁की',
#  '▁अयोग्य',
# ...

# %% [markdown]
# # NLTK Marathi

# %% [markdown]
# Let's Try this with nltk indian module

# %%
#import nltk
import nltk

# %%
#import indian corpuses from nltk

from nltk.corpus import indian
nltk.download('indian')
# Out:
# [nltk_data] Downloading package indian to
# [nltk_data]     C:\Users\buyre\AppData\Roaming\nltk_data...
# [nltk_data]   Package indian is already up-to-date!
# True

# %%
#Available Indian Corpuses are
indian.fileids()
# Out:
# ['bangla.pos', 'hindi.pos', 'marathi.pos', 'telugu.pos']

# %%
#Marathi Corpus

marathi = indian.sents('marathi.pos')

# %%
text= []
for word in marathi:
    text.append(word)
    print(word)
# Out:
# ["''", 'सनातनवाद्यांनी', 'व', 'प्रतिगाम्यांनी', 'समाज', 'रसातळाला', 'नेला', 'असताना', 'या', 'अंधारात', 'बाळशास्त्री', 'जांभेकर', 'यांनी', "'दर्पण'च्या", 'माध्यमातून', 'पहिली', 'ज्ञानज्योत', 'तेववली', ',', "''", 'असे', 'प्रतिपादन', 'नटसम्राट', 'प्रभाकर', 'पणशीकर', 'यांनी', 'केले', '.']
# ['दर्पणकार', 'बाळशास्त्री', 'जांभेकर', 'यांच्या', '१९५व्या', 'जयंतीनिमित्त', 'महाराष्ट्र', 'संपादक', 'परिषद', 'व', 'सिंधुदुर्ग', 'जिल्हा', 'मराठी', 'पत्रकार', 'संघाच्या', 'वतीने', 'तसेच', 'महाराष्ट्र', 'जर्नलिस्ट', 'फाउंडेशन', 'व', 'महाराष्ट्र', 'ग्रामीण', 'पत्रकार', 'संघाच्या', 'सहभागाने', 'अभिवादन', 'कार्यक्रम', 'आयोजित', 'केला', 'होता', '.']
# ['महाराष्ट्र', 'संपादक', 'परिषदेचे', 'कार्याध्यक्ष', 'यशवंत', 'पाध्ये', ',', 'जिल्हा', 'पत्रकार', 'संघाचे', 'अध्यक्ष', 'शशी', 'सावंत', 'यावेळी', 'उपस्थित', 'होते', '.']
# ...

# %%
text
# Out:
# [["''",
#   'सनातनवाद्यांनी',
#   'व',
#   'प्रतिगाम्यांनी',
#   'समाज',
#   'रसातळाला',
#   'नेला',
#   'असताना',
#   'या',
#   'अंधारात',
#   'बाळशास्त्री',
#   'जांभेकर',
#   'यांनी',
#   "'दर्पण'च्या",
#   'माध्यमातून',
#   'पहिली',
#   'ज्ञानज्योत',
#   'तेववली',
#   ',',
#   "''",
#   'असे',
#   'प्रतिपादन',
#   'नटसम्राट',
#   'प्रभाकर',
#   'पणशीकर',
#   'यांनी',
#   'केले',
#   '.'],
#  ['दर्पणकार',
#   'बाळशास्त्री',
#   'जांभेकर',
#   'यांच्या',
#   '१९५व्या',
#   'जयंतीनिमित्त',
#   'महाराष्ट्र',
#   'संपादक',
#   'परिषद',
#   'व',
#   'सिंधुदुर्ग',
#   'जिल्हा',
#   'मराठी',
#   'पत्रकार',
#   'संघाच्या',
#   'वतीने',
#   'तसेच',
#   'महाराष्ट्र',
#   'जर्नलिस्ट',
#   'फाउंडेशन',
#   'व',
#   'महाराष्ट्र',
#   'ग्रामीण',
#   'पत्रकार',
#   'संघाच्या',
#   'सहभागाने',
#   'अभिवादन',
#   'कार्यक्रम',
#   'आयोजित',
#   'केला',
#   'होता',
#   '.'],
#  ['महाराष्ट्र',
#   'संपादक',
#   'परिषदेचे',
#   'कार्याध्यक्ष',
#   'यशवंत',
#   'पाध्ये',
#   ',',
#   'जिल्हा',
# ...

# %%
#Now try for the stemmerporter for this marathi corpus
# Before try for some marathi words
import nltk
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('ज्ञानज्योत')
# Out:
# 'ज्ञानज्योत'

# %%
stemmerporter = PorterStemmer()
stemmerporter.stem('रसातळाला')
# Out:
# 'रसातळाला'

# %% [markdown]
# # Stemmer-Lemmatizer-POSTagger

# %% [markdown]
# It is found that the above words are not well stem of the marathi contents. Model needs to be trained for better stemming

# %% [markdown]
# NLTK English Corpus with stemmer and POSTagger

# %%
#Installed Inltk
#pip install inltk

# %%
## Tokenization
from nltk import sent_tokenize, word_tokenize
sequences = sent_tokenize(hermione_said)
seq_tokens = [word_tokenize(seq) for seq in sequences]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-7cd3c0c65835> in <module>
#       1 ## Tokenization
#       2 from nltk import sent_tokenize, word_tokenize
# ----> 3 sequences = sent_tokenize(hermione_said)
#       4 seq_tokens = [word_tokenize(seq) for seq in sequences]
#
# NameError: name 'hermione_said' is not defined

# %%
## Remove punctuation
no_punct_seq_tokens = []
for seq_token in seq_tokens:
    no_punct_seq_tokens.append([token for token in seq_token if token not in string.punctuation])
print(no_punct_seq_tokens)

# %%
# Using Porter Stemmer implementation in nltk
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(token) for seq in no_punct_seq_tokens for token in seq]
print(stemmed_tokens)

# %%
#Lemmatizer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
lm = WordNetLemmatizer()
lemmatized_tokens = [lm.lemmatize(token) for seq in no_punct_seq_tokens for token in seq]
print(lemmatized_tokens)

# %%
# let's see how it works!
print(lm.lemmatize("Books", pos="n"))

# %%
print(lm.lemmatize("books", pos="v"))

# %%
print(lm.lemmatize("continuing", pos = "v"))

# %%
print(lm.lemmatize("promising", pos = "v"))

# %%
# here I'm using the spacy library for POSTagger!
# get evolved with spacy library

# %%
import spacy

# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load("en_core_web_sm")

# Process whole documents
text = ("When Sebastian Thrun started working on self-driving cars at "
        "Google in 2007, few people outside of the company took him "
        "seriously. “I can tell you very senior CEOs of major American "
        "car companies would shake my hand and turn away because I wasn’t "
        "worth talking to,” said Thrun, in an interview with Recode earlier "
        "this week.")
doc = nlp(text)

# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])
print('\n\n')

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, '\t',entity.label_)
# Out:
# Noun phrases: ['Sebastian Thrun', 'self-driving cars', 'Google', 'few people', 'the company', 'him', 'I', 'you', 'very senior CEOs', 'major American car companies', 'my hand', 'I', 'Thrun', 'an interview', 'Recode']
# Verbs: ['start', 'work', 'drive', 'take', 'can', 'tell', 'would', 'shake', 'turn', 'talk', 'say']
#
#
#
# Sebastian 	 NORP
# Google 	 ORG
# 2007 	 DATE
# American 	 NORP
# Recode 	 ORG
# earlier this week 	 DATE

# %% [markdown]
# # Part of speech tagging

# %%
#token.pos takes values as for the POS of the word 
doc = nlp(text)

for token in doc:
    print(token.text,'\t\t',  token.pos_, '\t\t', token.tag_, '\t\t', token.is_stop)
# Out:
# When 		 ADV 		 WRB 		 True
# Sebastian 		 PROPN 		 NNP 		 False
# Thrun 		 PROPN 		 NNP 		 False
# started 		 VERB 		 VBD 		 False
# working 		 VERB 		 VBG 		 False
# on 		 ADP 		 IN 		 True
# self 		 NOUN 		 NN 		 False
# - 		 PUNCT 		 HYPH 		 False
# driving 		 VERB 		 VBG 		 False
# cars 		 NOUN 		 NNS 		 False
# at 		 ADP 		 IN 		 True
# Google 		 PROPN 		 NNP 		 False
# in 		 ADP 		 IN 		 True
# 2007 		 NUM 		 CD 		 False
# , 		 PUNCT 		 , 		 False
# few 		 ADJ 		 JJ 		 True
# people 		 NOUN 		 NNS 		 False
# outside 		 ADV 		 RB 		 False
# of 		 ADP 		 IN 		 True
# the 		 DET 		 DT 		 True
# company 		 NOUN 		 NN 		 False
# took 		 VERB 		 VBD 		 False
# him 		 PRON 		 PRP 		 True
# seriously 		 ADV 		 RB 		 False
# . 		 PUNCT 		 . 		 False
# “ 		 PUNCT 		 `` 		 False
# I 		 PRON 		 PRP 		 True
# can 		 VERB 		 MD 		 True
# tell 		 VERB 		 VB 		 False
# you 		 PRON 		 PRP 		 True
# very 		 ADV 		 RB 		 True
# senior 		 ADJ 		 JJ 		 False
# CEOs 		 NOUN 		 NNS 		 False
# ...

# %% [markdown]
# # HINDI POS

# %%
text = """स्कूल में कक्षा पहली से लेख लिखने के लिए बोला जाता है. लेख किसी भी टॉपिक पर उसके बारे
में विस्तार से लिखा जाता है. लेख के द्वारा विद्यार्थी दुनिया, जीवन, किसी व्यक्ति विशेष के बारे में करीब से जान पाता है. 
स्कूल, कॉलेज में लेख लिखने की प्रतियोगितायें भी होती है, जिनके द्वारा उनकी लेखन कला को आंका जाता है. 
हमने भी इसकी एक श्रंखला बनाई है, जिसमें बहुत सारे टॉपिक कवर करने की एक कोशिश की गई है।"""

# %%
from nltk.tag import tnt
from nltk.corpus import indian
train_data = indian.tagged_sents('hindi.pos')
tnt_pos_tagger = tnt.TnT()
tnt_pos_tagger.train(train_data)

# %%
from nltk import word_tokenize

tagged_words = (tnt_pos_tagger.tag(word_tokenize(text)))
for i in tagged_words:
    print(i[0],'\t   ','- ', i[1])
# Out:
# स्कूल 	    -  NN
# में 	    -  PREP
# कक्षा 	    -  NN
# पहली 	    -  JJ
# से 	    -  PREP
# लेख 	    -  Unk
# लिखने 	    -  Unk
# के 	    -  PREP
# लिए 	    -  PREP
# बोला 	    -  Unk
# जाता 	    -  VAUX
# है 	    -  VAUX
# . 	    -  SYM
# लेख 	    -  Unk
# किसी 	    -  QW
# भी 	    -  RP
# टॉपिक 	    -  Unk
# पर 	    -  PREP
# उसके 	    -  PRP
# बारे 	    -  NN
# में 	    -  PREP
# विस्तार 	    -  NN
# से 	    -  PREP
# लिखा 	    -  VFM
# जाता 	    -  VAUX
# है 	    -  VAUX
# . 	    -  SYM
# लेख 	    -  Unk
# के 	    -  PREP
# द्वारा 	    -  PREP
# विद्यार्थी 	    -  Unk
# दुनिया 	    -  NN
# , 	    -  PUNC
# जीवन 	    -  NN
# , 	    -  PUNC
# किसी 	    -  PRP
# व्यक्ति 	    -  NN
# विशेष 	    -  JJ
# के 	    -  PREP
# बारे 	    -  NN
# में 	    -  PREP
# करीब 	    -  INTF
# से 	    -  PREP
# जान 	    -  Unk
# पाता 	    -  Unk
# है 	    -  VFM
# . 	    -  SYM
# स्कूल 	    -  NN
# , 	    -  PUNC
# कॉलेज 	    -  Unk
# में 	    -  PREP
# लेख 	    -  Unk
# लिखने 	    -  Unk
# ...

# %%
tagged_words
# Out:
# [('स्कूल', 'NN'),
#  ('में', 'PREP'),
#  ('कक्षा', 'NN'),
#  ('पहली', 'JJ'),
#  ('से', 'PREP'),
#  ('लेख', 'Unk'),
#  ('लिखने', 'Unk'),
#  ('के', 'PREP'),
#  ('लिए', 'PREP'),
#  ('बोला', 'Unk'),
#  ('जाता', 'VAUX'),
#  ('है', 'VAUX'),
#  ('.', 'SYM'),
#  ('लेख', 'Unk'),
#  ('किसी', 'QW'),
#  ('भी', 'RP'),
#  ('टॉपिक', 'Unk'),
#  ('पर', 'PREP'),
#  ('उसके', 'PRP'),
#  ('बारे', 'NN'),
#  ('में', 'PREP'),
#  ('विस्तार', 'NN'),
#  ('से', 'PREP'),
#  ('लिखा', 'VFM'),
#  ('जाता', 'VAUX'),
#  ('है', 'VAUX'),
#  ('.', 'SYM'),
#  ('लेख', 'Unk'),
#  ('के', 'PREP'),
#  ('द्वारा', 'PREP'),
#  ('विद्यार्थी', 'Unk'),
#  ('दुनिया', 'NN'),
#  (',', 'PUNC'),
#  ('जीवन', 'NN'),
#  (',', 'PUNC'),
#  ('किसी', 'PRP'),
#  ('व्यक्ति', 'NN'),
#  ('विशेष', 'JJ'),
#  ('के', 'PREP'),
#  ('बारे', 'NN'),
#  ('में', 'PREP'),
#  ('करीब', 'INTF'),
#  ('से', 'PREP'),
#  ('जान', 'Unk'),
#  ('पाता', 'Unk'),
#  ('है', 'VFM'),
#  ('.', 'SYM'),
#  ('स्कूल', 'NN'),
#  (',', 'PUNC'),
#  ('कॉलेज', 'Unk'),
# ...
